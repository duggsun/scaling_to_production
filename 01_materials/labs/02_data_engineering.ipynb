# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# PEAK: No timezone found, symbol may be delisted
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 7.9616475105285645 seconds.
# Csv file size 14.150438999999999 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\dugga\AppData\Local\Temp\ipykernel_9588\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 2.253814458847046 seconds.
# Parquet file size 5.5532509999999995 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")
dd_px
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\backends.py:141, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     140 try:
# --> 141     return func(*args, **kwargs)
#     142 except Exception as e:
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:529, in read_parquet(path, columns, filters, categories, index, storage_options, engine, use_nullable_dtypes, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, **kwargs)
#     527     blocksize = None
# --> 529 read_metadata_result = engine.read_metadata(
#     530     fs,
#     531     paths,
#     532     categories=categories,
#     533     index=index,
#     534     use_nullable_dtypes=use_nullable_dtypes,
#     535     dtype_backend=dtype_backend,
#     536     gather_statistics=calculate_divisions,
#     537     filters=filters,
#     538     split_row_groups=split_row_groups,
#     539     blocksize=blocksize,
#     540     aggregate_files=aggregate_files,
#     541     ignore_metadata_file=ignore_metadata_file,
#     542     metadata_task_size=metadata_task_size,
#     543     parquet_file_extension=parquet_file_extension,
#     544     dataset=dataset_options,
#     545     read=read_options,
#     546     **other_options,
#     547 )
#     549 # In the future, we may want to give the engine the
#     550 # option to return a dedicated element for `common_kwargs`.
#     551 # However, to avoid breaking the API, we just embed this
#     552 # data in the first element of `parts` for now.
#     553 # The logic below is inteded to handle backward and forward
#     554 # compatibility with a user-defined engine.
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:545, in ArrowDatasetEngine.read_metadata(cls, fs, paths, categories, index, use_nullable_dtypes, dtype_backend, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, **kwargs)
#     544 # Stage 1: Collect general dataset information
# --> 545 dataset_info = cls._collect_dataset_info(
#     546     paths,
#     547     fs,
#     548     categories,
#     549     index,
#     550     gather_statistics,
#     551     filters,
#     552     split_row_groups,
#     553     blocksize,
#     554     aggregate_files,
#     555     ignore_metadata_file,
#     556     metadata_task_size,
#     557     parquet_file_extension,
#     558     kwargs,
#     559 )
#     561 # Stage 2: Generate output `meta`
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:1060, in ArrowDatasetEngine._collect_dataset_info(cls, paths, fs, categories, index, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, kwargs)
#    1059 if ds is None:
# -> 1060     ds = pa_ds.dataset(
#    1061         paths,
#    1062         filesystem=_wrapped_fs(fs),
#    1063         **_processed_dataset_kwargs,
#    1064     )
#    1066 # Get file_frag sample and extract physical_schema
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\dataset.py:765, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     764 if all(_is_path_like(elem) for elem in source):
# --> 765     return _filesystem_dataset(source, **kwargs)
#     766 elif all(isinstance(elem, Dataset) for elem in source):
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\dataset.py:443, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     442 if isinstance(source, (list, tuple)):
# --> 443     fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     444 else:
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\dataset.py:364, in _ensure_multiple_sources(paths, filesystem)
#     363 elif file_type == FileType.Directory:
# --> 364     raise IsADirectoryError(
#     365         'Path {} points to a directory, but only file paths are '
#     366         'supported. To construct a nested or union dataset pass '
#     367         'a list of dataset objects instead.'.format(info.path)
#     368     )
#     369 else:
#
# IsADirectoryError: Path c:/USC/scaling_to_production/05_src/data/prices/BEN/BEN_2000.parquet points to a directory, but only file paths are supported. To construct a nested or union dataset pass a list of dataset objects instead.
#
# The above exception was the direct cause of the following exception:
#
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[25], line 4
#       1 from glob import glob
#       3 parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
# ----> 4 dd_px = dd.read_parquet(parquet_files).set_index("ticker")
#       5 dd_px
#
# File c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\backends.py:143, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     141     return func(*args, **kwargs)
#     142 except Exception as e:
# --> 143     raise type(e)(
#     144         f"An error occurred while calling the {funcname(func)} "
#     145         f"method registered to the {self.backend} backend.\n"
#     146         f"Original Message: {e}"
#     147     ) from e
#
# IsADirectoryError: An error occurred while calling the read_parquet method registered to the pandas backend.
# Original Message: Path c:/USC/scaling_to_production/05_src/data/prices/BEN/BEN_2000.parquet points to a directory, but only file paths are supported. To construct a nested or union dataset pass a list of dataset objects instead.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\dugga\AppData\Local\Temp\ipykernel_9588\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.995831   35.126727   34.760212
# A      2013-12-03 00:00:00-05:00   34.635851   34.799476   34.400232
# A      2013-12-04 00:00:00-05:00   34.583488   35.231440   34.504951
# A      2013-12-05 00:00:00-05:00   34.917298   35.211821   34.766765
# A      2013-12-06 00:00:00-05:00   35.185641   35.951396   35.185641
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  128.551783  129.027053  127.274475
# YUM    2024-01-26 00:00:00-05:00  128.640891  129.403315  127.403198
# YUM    2024-01-29 00:00:00-05:00  127.828973  129.264694  127.026935
# YUM    2024-01-30 00:00:00-05:00  129.076565  129.928098  128.304245
# YUM    2024-01-31 00:00:00-05:00  130.155828  130.680609  127.987387
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.825661  2039962        0.0           0.0  2013          NaN
# A        34.642395  3462706        0.0           0.0  2013    34.825661
# A        35.067814  3377288        0.0           0.0  2013    34.642395
# A        35.015472  2530939        0.0           0.0  2013    35.067814
# A        35.885948  4268513        0.0           0.0  2013    35.015472
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.937943  1871700        0.0           0.0  2024   128.165619
# YUM     127.819061  1157000        0.0           0.0  2024   128.937943
# YUM     129.264694  1482100        0.0           0.0  2024   127.819061
# YUM     129.334000  1421500        0.0           0.0  2024   129.264694
# YUM     128.215134  2154200        0.0           0.0  2024   129.334000
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-06-29 17:41:56,850, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-29 17:41:56,850, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-29 17:41:56,850, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-29 17:41:56,850, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-29 17:41:56,887, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-29 17:41:56,887, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-29 17:41:56,887, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-29 17:41:56,887, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-29 17:41:56,902, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-29
# 2024-06-29 17:41:56,902, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:41:57,470, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-29 17:41:57,470, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-29 17:41:59,903, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-29 17:41:59,903, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-29 17:41:59,920, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-29
# 2024-06-29 17:41:59,920, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:00,456, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-29 17:42:00,456, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-29 17:42:05,726, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-29 17:42:05,726, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-29 17:42:05,734, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:05,734, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:06,647, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-29 17:42:06,647, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-29 17:42:10,784, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-29 17:42:10,784, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-29 17:42:10,784, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:10,784, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:11,006, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-29 17:42:11,006, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-29 17:42:11,748, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-29 17:42:11,748, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-29 17:42:11,763, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:11,763, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:12,017, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-06-29 17:42:12,017, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-06-29 17:42:13,302, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-06-29 17:42:13,302, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-06-29 17:42:13,318, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:13,318, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:13,670, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-06-29 17:42:13,670, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-06-29 17:42:15,026, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-06-29 17:42:15,026, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-06-29 17:42:15,026, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:15,026, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:15,278, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-06-29 17:42:15,278, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-06-29 17:42:16,618, data_manager.py, 73, INFO, Processing ticker AES
# 2024-06-29 17:42:16,618, data_manager.py, 73, INFO, Processing ticker AES
# 2024-06-29 17:42:16,618, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:16,618, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:17,123, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-29 17:42:17,123, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-29 17:42:19,085, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-29 17:42:19,085, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-29 17:42:19,090, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:19,090, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:19,558, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-29 17:42:19,558, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-29 17:42:20,959, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-29 17:42:20,959, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-29 17:42:20,975, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:20,975, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:21,237, data_manager.py, 82, INFO, Saving data for A by year
# 2024-06-29 17:42:21,237, data_manager.py, 82, INFO, Saving data for A by year
# 2024-06-29 17:42:22,651, data_manager.py, 73, INFO, Processing ticker APD
# 2024-06-29 17:42:22,651, data_manager.py, 73, INFO, Processing ticker APD
# 2024-06-29 17:42:22,651, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:22,651, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:23,003, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-06-29 17:42:23,003, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-06-29 17:42:24,522, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-06-29 17:42:24,522, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-06-29 17:42:24,538, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:24,538, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:24,631, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-29 17:42:24,631, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-29 17:42:24,914, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-29 17:42:24,914, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-29 17:42:24,914, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:24,914, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:25,134, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-29 17:42:25,134, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-29 17:42:26,535, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-29 17:42:26,535, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-29 17:42:26,535, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:26,535, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:27,085, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-29 17:42:27,085, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-29 17:42:29,704, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-29 17:42:29,704, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-29 17:42:29,704, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:29,704, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:30,050, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-06-29 17:42:30,050, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-06-29 17:42:32,310, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-06-29 17:42:32,310, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-06-29 17:42:32,310, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:32,310, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:32,592, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-06-29 17:42:32,592, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-06-29 17:42:34,342, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-06-29 17:42:34,342, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-06-29 17:42:34,342, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:34,342, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:34,563, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-06-29 17:42:34,563, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-06-29 17:42:35,206, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-06-29 17:42:35,206, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-06-29 17:42:35,206, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:35,206, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:35,553, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-06-29 17:42:35,553, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-06-29 17:42:36,874, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-06-29 17:42:36,874, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-06-29 17:42:36,874, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:36,874, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:37,337, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-06-29 17:42:37,337, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-06-29 17:42:38,690, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-06-29 17:42:38,690, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-06-29 17:42:38,690, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:38,690, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:38,940, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-06-29 17:42:38,940, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-06-29 17:42:40,535, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-06-29 17:42:40,535, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-06-29 17:42:40,539, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:40,539, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:40,793, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-06-29 17:42:40,793, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-06-29 17:42:42,337, data_manager.py, 73, INFO, Processing ticker MO
# 2024-06-29 17:42:42,337, data_manager.py, 73, INFO, Processing ticker MO
# 2024-06-29 17:42:42,337, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:42,337, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:42,726, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-06-29 17:42:42,726, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-06-29 17:42:44,100, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-06-29 17:42:44,100, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-06-29 17:42:44,100, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:44,100, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:44,618, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-06-29 17:42:44,618, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-06-29 17:42:46,581, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-06-29 17:42:46,581, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-06-29 17:42:46,581, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:46,581, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:46,773, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-06-29 17:42:46,773, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-06-29 17:42:47,741, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-06-29 17:42:47,741, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-06-29 17:42:47,741, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:47,741, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:48,020, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-06-29 17:42:48,020, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-06-29 17:42:50,169, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-06-29 17:42:50,169, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-06-29 17:42:50,184, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:50,184, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:50,403, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-06-29 17:42:50,403, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-06-29 17:42:52,895, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-06-29 17:42:52,895, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-06-29 17:42:52,898, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:52,898, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:53,439, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-06-29 17:42:53,439, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-06-29 17:42:56,985, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-06-29 17:42:56,985, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-06-29 17:42:56,985, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-06-29
# 2024-06-29 17:42:56,985, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:42:57,557, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-06-29 17:42:57,557, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-06-29 17:43:00,630, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-06-29 17:43:00,630, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-06-29 17:43:00,642, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:00,642, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:01,025, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-06-29 17:43:01,025, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-06-29 17:43:03,877, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-06-29 17:43:03,877, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-06-29 17:43:03,884, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:03,884, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:04,400, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-06-29 17:43:04,400, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-06-29 17:43:08,524, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-06-29 17:43:08,524, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-06-29 17:43:08,524, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:08,524, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:08,947, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-06-29 17:43:08,947, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-06-29 17:43:11,346, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-06-29 17:43:11,346, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-06-29 17:43:11,346, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:11,346, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:11,990, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-06-29 17:43:11,990, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-06-29 17:43:14,665, data_manager.py, 73, INFO, Processing ticker AME
# 2024-06-29 17:43:14,665, data_manager.py, 73, INFO, Processing ticker AME
# 2024-06-29 17:43:14,681, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:14,681, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:15,179, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-06-29 17:43:15,179, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-06-29 17:43:17,421, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-06-29 17:43:17,421, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-06-29 17:43:17,421, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:17,421, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:17,719, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-06-29 17:43:17,719, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-06-29 17:43:21,303, data_manager.py, 73, INFO, Processing ticker APH
# 2024-06-29 17:43:21,303, data_manager.py, 73, INFO, Processing ticker APH
# 2024-06-29 17:43:21,303, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:21,303, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:21,896, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-06-29 17:43:21,896, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-06-29 17:43:23,584, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-06-29 17:43:23,584, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-06-29 17:43:23,584, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:23,584, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:24,068, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-06-29 17:43:24,068, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-06-29 17:43:26,899, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-06-29 17:43:26,899, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-06-29 17:43:26,914, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:26,914, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:27,274, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-06-29 17:43:27,274, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-06-29 17:43:28,914, data_manager.py, 73, INFO, Processing ticker AON
# 2024-06-29 17:43:28,914, data_manager.py, 73, INFO, Processing ticker AON
# 2024-06-29 17:43:28,914, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:28,914, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:29,412, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-06-29 17:43:29,412, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-06-29 17:43:31,596, data_manager.py, 73, INFO, Processing ticker APA
# 2024-06-29 17:43:31,596, data_manager.py, 73, INFO, Processing ticker APA
# 2024-06-29 17:43:31,596, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:31,596, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:32,218, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-06-29 17:43:32,218, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-06-29 17:43:34,703, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-06-29 17:43:34,703, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-06-29 17:43:34,703, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:34,703, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:35,314, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-06-29 17:43:35,314, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-06-29 17:43:37,378, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-06-29 17:43:37,378, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-06-29 17:43:37,393, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:37,393, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:37,878, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-06-29 17:43:37,878, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-06-29 17:43:40,498, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-06-29 17:43:40,498, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-06-29 17:43:40,514, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:40,514, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:41,217, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-06-29 17:43:41,217, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-06-29 17:43:44,226, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-06-29 17:43:44,226, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-06-29 17:43:44,228, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:44,228, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:45,069, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-06-29 17:43:45,069, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-06-29 17:43:52,211, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-06-29 17:43:52,211, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-06-29 17:43:52,230, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:52,230, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:53,035, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-06-29 17:43:53,035, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-06-29 17:43:56,480, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-06-29 17:43:56,480, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-06-29 17:43:56,480, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:56,480, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:56,748, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-06-29 17:43:56,748, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-06-29 17:43:58,647, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-06-29 17:43:58,647, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-06-29 17:43:58,664, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-06-29
# 2024-06-29 17:43:58,664, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:43:59,195, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-06-29 17:43:59,195, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-06-29 17:44:02,034, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-06-29 17:44:02,034, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-06-29 17:44:02,041, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:02,041, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:02,593, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-06-29 17:44:02,593, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-06-29 17:44:07,622, data_manager.py, 73, INFO, Processing ticker T
# 2024-06-29 17:44:07,622, data_manager.py, 73, INFO, Processing ticker T
# 2024-06-29 17:44:07,628, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:07,628, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:08,426, data_manager.py, 82, INFO, Saving data for T by year
# 2024-06-29 17:44:08,426, data_manager.py, 82, INFO, Saving data for T by year
# 2024-06-29 17:44:12,716, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-06-29 17:44:12,716, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-06-29 17:44:12,723, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:12,723, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:13,197, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-06-29 17:44:13,197, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-06-29 17:44:15,895, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-06-29 17:44:15,895, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-06-29 17:44:15,895, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:15,895, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:16,381, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-06-29 17:44:16,381, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-06-29 17:44:18,479, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-06-29 17:44:18,479, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-06-29 17:44:18,479, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:18,479, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:19,073, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-06-29 17:44:19,073, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-06-29 17:44:21,619, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-06-29 17:44:21,619, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-06-29 17:44:21,619, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:21,619, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:22,120, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-06-29 17:44:22,120, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-06-29 17:44:23,479, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-06-29 17:44:23,479, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-06-29 17:44:23,479, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:23,479, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:23,807, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-06-29 17:44:23,807, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-06-29 17:44:25,168, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-06-29 17:44:25,168, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-06-29 17:44:25,184, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:25,184, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:25,824, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-06-29 17:44:25,824, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-06-29 17:44:27,340, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-06-29 17:44:27,340, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-06-29 17:44:27,340, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:27,340, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:27,699, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-06-29 17:44:27,699, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-06-29 17:44:29,059, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-06-29 17:44:29,059, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-06-29 17:44:29,074, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:29,074, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:29,403, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-06-29 17:44:29,403, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-06-29 17:44:30,863, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-06-29 17:44:30,863, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-06-29 17:44:30,880, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:30,880, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:31,297, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-06-29 17:44:31,297, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-06-29 17:44:35,013, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-06-29 17:44:35,013, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-06-29 17:44:35,013, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:35,013, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:35,463, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-06-29 17:44:35,463, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-06-29 17:44:37,194, data_manager.py, 73, INFO, Processing ticker BK
# 2024-06-29 17:44:37,194, data_manager.py, 73, INFO, Processing ticker BK
# 2024-06-29 17:44:37,199, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:37,199, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:37,843, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-06-29 17:44:37,843, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-06-29 17:44:39,367, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-06-29 17:44:39,367, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-06-29 17:44:39,371, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:39,371, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:39,762, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-06-29 17:44:39,762, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-06-29 17:44:41,641, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-06-29 17:44:41,641, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-06-29 17:44:41,641, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:41,641, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:42,064, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-06-29 17:44:42,064, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-06-29 17:44:45,000, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-06-29 17:44:45,000, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-06-29 17:44:45,008, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:45,008, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:46,182, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-06-29 17:44:46,182, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-06-29 17:44:49,460, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-06-29 17:44:49,460, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-06-29 17:44:49,464, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:49,464, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2024-06-29 17:44:50,950, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-06-29 17:44:50,950, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-06-29 17:44:50,966, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-06-29 17:44:50,966, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-06-29 17:44:50,981, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-06-29 17:44:50,981, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-06-29 17:44:50,986, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:50,986, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:51,293, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-06-29 17:44:51,293, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-06-29 17:44:53,893, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-06-29 17:44:53,893, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-06-29 17:44:53,897, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:53,897, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:54,212, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-06-29 17:44:54,212, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-06-29 17:44:56,041, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-06-29 17:44:56,041, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-06-29 17:44:56,041, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:56,041, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:56,541, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-06-29 17:44:56,541, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-06-29 17:44:57,981, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-06-29 17:44:57,981, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-06-29 17:44:57,981, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-06-29
# 2024-06-29 17:44:57,981, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:44:58,590, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-06-29 17:44:58,590, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-06-29 17:45:00,231, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-06-29 17:45:00,231, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-06-29 17:45:00,231, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:00,231, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:00,783, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-06-29 17:45:00,783, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-06-29 17:45:02,175, data_manager.py, 73, INFO, Processing ticker BX
# 2024-06-29 17:45:02,175, data_manager.py, 73, INFO, Processing ticker BX
# 2024-06-29 17:45:02,181, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:02,181, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:03,041, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-06-29 17:45:03,041, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-06-29 17:45:04,662, data_manager.py, 73, INFO, Processing ticker BA
# 2024-06-29 17:45:04,662, data_manager.py, 73, INFO, Processing ticker BA
# 2024-06-29 17:45:04,662, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:04,662, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:05,262, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-06-29 17:45:05,262, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-06-29 17:45:07,329, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-06-29 17:45:07,329, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-06-29 17:45:07,329, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:07,329, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:07,907, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-06-29 17:45:07,907, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-06-29 17:45:11,917, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-06-29 17:45:11,917, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-06-29 17:45:11,917, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:11,917, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:12,536, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-06-29 17:45:12,536, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-06-29 17:45:14,267, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-06-29 17:45:14,267, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-06-29 17:45:14,270, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:14,270, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:14,700, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-06-29 17:45:14,700, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-06-29 17:45:16,333, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-06-29 17:45:16,333, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-06-29 17:45:16,333, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:16,333, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:16,572, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-06-29 17:45:16,572, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-06-29 17:45:18,351, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-06-29 17:45:18,351, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-06-29 17:45:18,351, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:18,351, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:18,916, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-06-29 17:45:18,916, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-06-29 17:45:23,565, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-06-29 17:45:23,565, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-06-29 17:45:23,565, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:23,565, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:23,799, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-06-29 17:45:23,799, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-06-29 17:45:24,674, data_manager.py, 73, INFO, Processing ticker BR
# 2024-06-29 17:45:24,674, data_manager.py, 73, INFO, Processing ticker BR
# 2024-06-29 17:45:24,674, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-06-29
# 2024-06-29 17:45:24,674, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 17:45:24,934, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-06-29 17:45:24,934, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-06-29 17:45:29,319, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-06-29 17:45:29,319, data_manager.py, 73, INFO, Processing ticker BRO
# ...
#
# 1 Failed download:
# ['WY']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000274319EC1F0>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,076, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-06-29 17:58:07,076, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-06-29 17:58:07,082, data_manager.py, 100, WARNING, No data found for WY
# 2024-06-29 17:58:07,082, data_manager.py, 100, WARNING, No data found for WY
# 2024-06-29 17:58:07,088, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-06-29 17:58:07,088, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-06-29 17:58:07,105, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,105, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WHR']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027423828070>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,218, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-06-29 17:58:07,218, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-06-29 17:58:07,219, data_manager.py, 100, WARNING, No data found for WHR
# 2024-06-29 17:58:07,219, data_manager.py, 100, WARNING, No data found for WHR
# 2024-06-29 17:58:07,236, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-06-29 17:58:07,236, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-06-29 17:58:07,236, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,236, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WMB']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002742EEDF370>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,426, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-06-29 17:58:07,426, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-06-29 17:58:07,434, data_manager.py, 100, WARNING, No data found for WMB
# 2024-06-29 17:58:07,434, data_manager.py, 100, WARNING, No data found for WMB
# 2024-06-29 17:58:07,439, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-06-29 17:58:07,439, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-06-29 17:58:07,444, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,444, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WTW']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000274319EC4F0>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,604, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-06-29 17:58:07,604, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-06-29 17:58:07,608, data_manager.py, 100, WARNING, No data found for WTW
# 2024-06-29 17:58:07,608, data_manager.py, 100, WARNING, No data found for WTW
# 2024-06-29 17:58:07,620, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-06-29 17:58:07,620, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-06-29 17:58:07,623, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,623, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GWW']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002742EB964C0>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,686, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-06-29 17:58:07,686, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-06-29 17:58:07,686, data_manager.py, 100, WARNING, No data found for GWW
# 2024-06-29 17:58:07,686, data_manager.py, 100, WARNING, No data found for GWW
# 2024-06-29 17:58:07,705, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-06-29 17:58:07,705, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-06-29 17:58:07,705, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,705, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WYNN']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002742235E850>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,751, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-06-29 17:58:07,751, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-06-29 17:58:07,767, data_manager.py, 100, WARNING, No data found for WYNN
# 2024-06-29 17:58:07,767, data_manager.py, 100, WARNING, No data found for WYNN
# 2024-06-29 17:58:07,767, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-06-29 17:58:07,767, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-06-29 17:58:07,784, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,784, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XEL']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000274341A7040>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,834, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-06-29 17:58:07,834, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-06-29 17:58:07,834, data_manager.py, 100, WARNING, No data found for XEL
# 2024-06-29 17:58:07,834, data_manager.py, 100, WARNING, No data found for XEL
# 2024-06-29 17:58:07,850, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-06-29 17:58:07,850, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-06-29 17:58:07,850, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,850, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XYL']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000274221F4AF0>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,903, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-06-29 17:58:07,903, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-06-29 17:58:07,917, data_manager.py, 100, WARNING, No data found for XYL
# 2024-06-29 17:58:07,917, data_manager.py, 100, WARNING, No data found for XYL
# 2024-06-29 17:58:07,925, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-06-29 17:58:07,925, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-06-29 17:58:07,934, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,934, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['YUM']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000274301009A0>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:07,968, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-29 17:58:07,968, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-29 17:58:07,968, data_manager.py, 100, WARNING, No data found for YUM
# 2024-06-29 17:58:07,968, data_manager.py, 100, WARNING, No data found for YUM
# 2024-06-29 17:58:07,988, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-29 17:58:07,988, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-29 17:58:07,992, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:07,992, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZBRA']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000274302E9C70>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:08,083, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-06-29 17:58:08,083, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-06-29 17:58:08,087, data_manager.py, 100, WARNING, No data found for ZBRA
# 2024-06-29 17:58:08,087, data_manager.py, 100, WARNING, No data found for ZBRA
# 2024-06-29 17:58:08,092, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-06-29 17:58:08,092, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-06-29 17:58:08,117, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:08,117, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZBH']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002743190C130>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:08,155, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-06-29 17:58:08,155, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-06-29 17:58:08,160, data_manager.py, 100, WARNING, No data found for ZBH
# 2024-06-29 17:58:08,160, data_manager.py, 100, WARNING, No data found for ZBH
# 2024-06-29 17:58:08,167, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-06-29 17:58:08,167, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-06-29 17:58:08,171, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:08,171, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZION']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002742EA36FD0>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:08,209, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-29 17:58:08,209, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-29 17:58:08,216, data_manager.py, 100, WARNING, No data found for ZION
# 2024-06-29 17:58:08,216, data_manager.py, 100, WARNING, No data found for ZION
# 2024-06-29 17:58:08,221, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-29 17:58:08,221, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-29 17:58:08,227, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-29
# 2024-06-29 17:58:08,227, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZTS']: ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'query2.finance.yahoo.com\', port=443): Max retries exceeded with url: /v8/finance/chart/%ticker%?period1=946702800&period2=1719633600&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=ZfLGDkQ3AtI (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002742EC09C70>: Failed to resolve \'query2.finance.yahoo.com\' ([Errno 11001] getaddrinfo failed)"))'))
# 2024-06-29 17:58:08,307, data_manager.py, 82, INFO, Saving data for ZTS by year
# 2024-06-29 17:58:08,307, data_manager.py, 82, INFO, Saving data for ZTS by year
# 2024-06-29 17:58:08,320, data_manager.py, 100, WARNING, No data found for ZTS
# 2024-06-29 17:58:08,320, data_manager.py, 100, WARNING, No data found for ZTS

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-06-29 17:58:08,468, data_manager.py, 117, INFO, Creating features data.
# 2024-06-29 17:58:08,468, data_manager.py, 117, INFO, Creating features data.
# 2024-06-29 17:58:08,474, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# 2024-06-29 17:58:08,474, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-06-29 17:58:11,234, data_manager.py, 136, INFO, Creating features
# 2024-06-29 17:58:11,234, data_manager.py, 136, INFO, Creating features
# c:\USC\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:138: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-06-29 17:58:11,401, data_manager.py, 154, INFO, Creating target
# 2024-06-29 17:58:11,401, data_manager.py, 154, INFO, Creating target
# c:\USC\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:155: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-06-29 17:58:11,517, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-06-29 17:58:11,517, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
# ...
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# c:\Users\dugga\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
